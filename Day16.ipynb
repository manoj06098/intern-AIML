# %% [markdown]
# # Internship
# ## Manoj.M
# ## Day 16
# ## Date: 11th Jun,2019

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("data2/cars1.csv")

# %%
df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df.shape
# Out:
# (81, 5)

# %%
df.columns
# Out:
# Index(['HP', 'MPG', 'VOL', 'SP', 'WT'], dtype='object')

# %%
sns.pairplot(df.iloc[:,:])

# %%
import statsmodels.formula.api as smf

# %%
ml1=smf.ols("MPG~HP+VOL+SP+WT",data=df).fit()

# %%
ml1.params
# Out:
# Intercept    30.677336
# HP           -0.205444
# VOL          -0.336051
# SP            0.395627
# WT            0.400574
# dtype: float64

# %%
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     63.80
# Date:                Tue, 11 Jun 2019   Prob (F-statistic):           1.54e-23
# Time:                        15:29:46   Log-Likelihood:                -233.96
# No. Observations:                  81   AIC:                             477.9
# Df Residuals:                      76   BIC:                             489.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     30.6773     14.900      2.059      0.043       1.001      60.354
# ...

# %%
df.head()
# Out:
#    HP        MPG  VOL          SP         WT
# 0  49  53.700681   89  104.185353  28.762059
# 1  55  50.013401   92  105.461264  30.466833
# 2  55  50.013401   92  105.461264  30.193597
# 3  70  45.696322   92  113.461264  30.632114
# 4  53  50.504232   92  104.461264  29.889149

# %%
ml2=smf.ols("MPG~VOL",data=df).fit()

# %%
ml2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.280
# Model:                            OLS   Adj. R-squared:                  0.271
# Method:                 Least Squares   F-statistic:                     30.71
# Date:                Tue, 11 Jun 2019   Prob (F-statistic):           3.82e-07
# Time:                        15:34:19   Log-Likelihood:                -280.28
# No. Observations:                  81   AIC:                             564.6
# Df Residuals:                      79   BIC:                             569.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     55.8171      3.957     14.106      0.000      47.941      63.693
# ...

# %%
ml3=smf.ols("MPG~WT",data=df).fit()

# %%
ml3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.277
# Model:                            OLS   Adj. R-squared:                  0.268
# Method:                 Least Squares   F-statistic:                     30.34
# Date:                Tue, 11 Jun 2019   Prob (F-statistic):           4.38e-07
# Time:                        15:34:42   Log-Likelihood:                -280.42
# No. Observations:                  81   AIC:                             564.8
# Df Residuals:                      79   BIC:                             569.6
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     55.2296      3.876     14.249      0.000      47.514      62.945
# ...

# %%
ml4=smf.ols("MPG~VOL+WT",data=df).fit()

# %%
ml4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.282
# Model:                            OLS   Adj. R-squared:                  0.264
# Method:                 Least Squares   F-statistic:                     15.33
# Date:                Tue, 11 Jun 2019   Prob (F-statistic):           2.43e-06
# Time:                        15:36:47   Log-Likelihood:                -280.16
# No. Observations:                  81   AIC:                             566.3
# Df Residuals:                      78   BIC:                             573.5
# Df Model:                           2
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     56.8847      4.534     12.546      0.000      47.858      65.912
# ...

# %%
import statsmodels.api as sm

# %%
sm.graphics.influence_plot(ml1)

# %%
cars_new=df.drop(df.index[[70,76]],axis=0,inplace=False)

# %%
cars_new
# Out:
#      HP        MPG  VOL          SP         WT
# 0    49  53.700681   89  104.185353  28.762059
# 1    55  50.013401   92  105.461264  30.466833
# 2    55  50.013401   92  105.461264  30.193597
# 3    70  45.696322   92  113.461264  30.632114
# 4    53  50.504232   92  104.461264  29.889149
# 5    70  45.696322   89  113.185353  29.591768
# 6    55  50.013401   92  105.461264  30.308480
# 7    62  46.716554   50  102.598513  15.847758
# 8    62  46.716554   50  102.598513  16.359484
# 9    80  42.299078   94  115.645204  30.920154
# 10   73  44.652834   89  111.185353  29.363341
# 11   92  39.354094   50  117.598513  15.753535
# 12   92  39.354094   99  122.105055  32.813592
# 13   73  44.652834   89  111.185353  29.378436
# 14   66  45.734893   89  108.185353  29.347279
# 15   73  44.652834   89  111.185353  29.604527
# 16   78  42.789909   91  114.369293  29.535784
# 17   92  39.354094   50  117.598513  16.194122
# 18   78  42.789909   91  114.369293  29.929394
# ...

# %%
cars_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 0 to 80
# Data columns (total 5 columns):
# HP     79 non-null int64
# MPG    79 non-null float64
# VOL    79 non-null int64
# SP     79 non-null float64
# WT     79 non-null float64
# dtypes: float64(3), int64(2)
# memory usage: 3.7 KB

# %%
import statsmodels.formula.api as smf

# %%
ml5=smf.ols("MPG~HP+VOL+SP+WT",data=df).fit()

# %%
ml5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.771
# Model:                            OLS   Adj. R-squared:                  0.758
# Method:                 Least Squares   F-statistic:                     63.80
# Date:                Tue, 11 Jun 2019   Prob (F-statistic):           1.54e-23
# Time:                        16:03:57   Log-Likelihood:                -233.96
# No. Observations:                  81   AIC:                             477.9
# Df Residuals:                      76   BIC:                             489.9
# Df Model:                           4
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     30.6773     14.900      2.059      0.043       1.001      60.354
# ...

# %%
rsq_hp=smf.ols("HP ~ VOL+SP+WT",data=df).fit().rsquared

# %%
vif_hp=1/(1-rsq_hp)

# %%
vif_hp
# Out:
# 19.926588974998563

# %%
rsq_vol=smf.ols("VOL ~ HP+SP+WT",data=df).fit().rsquared

# %%
vif_vol=1/(1-rsq_vol)

# %%
vif_vol
# Out:
# 638.8060836592878

# %%
rsq_sp=smf.ols("SP ~ HP+VOL+WT",data=df).fit().rsquared

# %%
vif_sp=1/(1-rsq_sp)

# %%
vif_sp
# Out:
# 20.007638783050126

# %%
rsq_wt=smf.ols("WT ~ HP+VOL+SP",data=df).fit().rsquared

# %%
vif_wt=1/(1-rsq_wt)

# %%
vif_wt
# Out:
# 639.5338175572624

# %%
dictionary={"variables":["HP","VOL","WT","SP"],"values":[vif_hp,vif_vol,vif_wt,vif_sp]}

# %%
dictionary
# Out:
# {'variables': ['HP', 'VOL', 'WT', 'SP'],
#  'values': [19.926588974998563,
#   638.8060836592878,
#   639.5338175572624,
#   20.007638783050126]}

# %%
mk=pd.DataFrame(dictionary)

# %%
mk
# Out:
#   variables      values
# 0        HP   19.926589
# 1       VOL  638.806084
# 2        WT  639.533818
# 3        SP   20.007639

# %%
sm.graphics.plot_partregress_grid(ml1)

# %%
final_m1 = smf.ols('MPG ~ VOL+SP+HP', data=df).fit()
final_m1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                    MPG   R-squared:                       0.770
# Model:                            OLS   Adj. R-squared:                  0.761
# Method:                 Least Squares   F-statistic:                     86.11
# Date:                Tue, 11 Jun 2019   Prob (F-statistic):           1.56e-24
# Time:                        16:26:43   Log-Likelihood:                -233.99
# No. Observations:                  81   AIC:                             476.0
# Df Residuals:                      77   BIC:                             485.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     29.9234     14.466      2.069      0.042       1.118      58.729
# ...
