# %% [markdown]
# # Internship
# ## Manoj.M
# ## Day 11
# ## Date 5th Jun,19

# %% [markdown]
# # missing values

# %%
import os
os.getcwd()
# Out:
# 'E:\\mobile data\\Documents\\.SHAREit'

# %%
os.chdir("E:\mobile data\Documents\.SHAREit")

# %%
import pandas as pd
pd.read_csv("D:\Data\data1\AppleStore.csv")
# Out:
#       Unnamed: 0          id  \
# 0              1   281656475
# 1              2   281796108
# 2              3   281940292
# 3              4   282614216
# 4              5   282935706
# 5              6   283619399
# 6              7   283646709
# 7              8   284035177
# 8              9   284666222
# 9             10   284736660
# 10            11   284791396
# 11            12   284815117
# 12            13   284815942
# 13            14   284847138
# 14            15   284862767
# 15            16   284876795
# 16            17   284882215
# 17            18   284910350
# 18            20   284993459
# 19            21   285005463
# 20            22   285946052
# 21            23   285994151
# 22            24   286058814
# 23            25   286070473
# 24            27   286799607
# 25            28   286906691
# 26            29   286911400
# 27            31   288113403
# 28            32   288120394
# 29            33   288419283
# ...          ...         ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import scale

# %%
df=pd.read_csv("D:\Data\data1\Weather_data.csv")

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df.fillna(method="ffill")#for ward  fillinf
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017         32.0        7.0  Sunny
# 2  1/3/2017         28.0        7.0   Snow
# 3  1/4/2017         28.0        7.0      0
# 4  1/5/2017         32.0        7.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df.fillna(method="bfill")#back ward filling
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017         28.0        7.0  Sunny
# 2  1/3/2017         28.0        7.0   Snow
# 3  1/4/2017         32.0        7.0      0
# 4  1/5/2017         32.0        2.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df.fillna(0)#fillingwith own value
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          0.0        7.0  Sunny
# 2  1/3/2017         28.0        0.0   Snow
# 3  1/4/2017          0.0        7.0      0
# 4  1/5/2017         32.0        0.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df.fillna(5)#fillingwith own value
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          5.0        7.0  Sunny
# 2  1/3/2017         28.0        5.0   Snow
# 3  1/4/2017          5.0        7.0      0
# 4  1/5/2017         32.0        5.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df.fillna(method="ffill")
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017         32.0        7.0  Sunny
# 2  1/3/2017         28.0        7.0   Snow
# 3  1/4/2017         28.0        7.0      0
# 4  1/5/2017         32.0        7.0   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
df.interpolate()#it bases on the data it will predict the values
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017         30.0        7.0  Sunny
# 2  1/3/2017         28.0        7.0   Snow
# 3  1/4/2017         30.0        7.0      0
# 4  1/5/2017         32.0        4.5   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
from sklearn.preprocessing import Imputer

# %%
imputer = Imputer(missing_values = 'NaN', strategy = "mean", axis = 0)
# Out:
# C:\Users\manoj kumar\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:58: DeprecationWarning: Class Imputer is deprecated; Imputer was deprecated in version 0.20 and will be removed in 0.22. Import impute.SimpleImputer from sklearn instead.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017          NaN        7.0  Sunny
# 2  1/3/2017         28.0        NaN   Snow
# 3  1/4/2017          NaN        7.0      0
# 4  1/5/2017         32.0        NaN   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
imputer=imputer.fit(df.iloc[:,1:3])

# %%
df.iloc[:,1:3] = imputer.transform(df.iloc[:,1:3])

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017         31.4        7.0  Sunny
# 2  1/3/2017         28.0        5.4   Snow
# 3  1/4/2017         31.4        7.0      0
# 4  1/5/2017         32.0        5.4   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %% [markdown]
# # handling the categorial values

# %%
col=["event"]
df[col]=df[col].fillna(df.median().iloc[0])

# %%
df
# Out:
#         day  temperature  windspeed  event
# 0  1/1/2017         32.0        6.0   Rain
# 1  1/2/2017         31.4        7.0  Sunny
# 2  1/3/2017         28.0        5.4   Snow
# 3  1/4/2017         31.4        7.0      0
# 4  1/5/2017         32.0        5.4   Rain
# 5  1/6/2017         31.0        2.0  Sunny
# 6  1/6/2017         34.0        5.0      0

# %%
price=pd.read_csv("D:\Data\data1\homeprices.csv")

# %%
price
# Out:
#                town  area   price
# 0   monroe township  2600  550000
# 1   monroe township  3000  565000
# 2   monroe township  3200  610000
# 3   monroe township  3600  680000
# 4   monroe township  4000  725000
# 5      west windsor  2600  585000
# 6      west windsor  2800  615000
# 7      west windsor  3300  650000
# 8      west windsor  3600  710000
# 9       robinsville  2600  575000
# 10      robinsville  2900  600000
# 11      robinsville  3100  620000
# 12      robinsville  3600  695000

# %%
dummy_set=pd.get_dummies(price.town)

# %%
dummy_set
# Out:
#     monroe township  robinsville  west windsor
# 0                 1            0             0
# 1                 1            0             0
# 2                 1            0             0
# 3                 1            0             0
# 4                 1            0             0
# 5                 0            0             1
# 6                 0            0             1
# 7                 0            0             1
# 8                 0            0             1
# 9                 0            1             0
# 10                0            1             0
# 11                0            1             0
# 12                0            1             0

# %%
merged=pd.concat([price,dummy_set],axis=1)

# %%
merged
# Out:
#                town  area   price  monroe township  robinsville  west windsor
# 0   monroe township  2600  550000                1            0             0
# 1   monroe township  3000  565000                1            0             0
# 2   monroe township  3200  610000                1            0             0
# 3   monroe township  3600  680000                1            0             0
# 4   monroe township  4000  725000                1            0             0
# 5      west windsor  2600  585000                0            0             1
# 6      west windsor  2800  615000                0            0             1
# 7      west windsor  3300  650000                0            0             1
# 8      west windsor  3600  710000                0            0             1
# 9       robinsville  2600  575000                0            1             0
# 10      robinsville  2900  600000                0            1             0
# ...

# %%
pd.get_dummies(price,columns=['town'],drop_first=True)
# Out:
#     area   price  town_robinsville  town_west windsor
# 0   2600  550000                 0                  0
# 1   3000  565000                 0                  0
# 2   3200  610000                 0                  0
# 3   3600  680000                 0                  0
# 4   4000  725000                 0                  0
# 5   2600  585000                 0                  1
# 6   2800  615000                 0                  1
# 7   3300  650000                 0                  1
# 8   3600  710000                 0                  1
# 9   2600  575000                 1                  0
# 10  2900  600000                 1                  0
# 11  3100  620000                 1                  0
# 12  3600  695000                 1                  0

# %%
final = merged.drop(['town','west windsor'], axis = 1)

# %%
final
# Out:
#     area   price  monroe township  robinsville
# 0   2600  550000                1            0
# 1   3000  565000                1            0
# 2   3200  610000                1            0
# 3   3600  680000                1            0
# 4   4000  725000                1            0
# 5   2600  585000                0            0
# 6   2800  615000                0            0
# 7   3300  650000                0            0
# 8   3600  710000                0            0
# 9   2600  575000                0            1
# 10  2900  600000                0            1
# 11  3100  620000                0            1
# 12  3600  695000                0            1

# %% [markdown]
# # Dummy Variables using LabelEncoder

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
dlf=price

# %%
dlf.town=le.fit_transform(price.town)

# %%
dlf
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
price
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
rom sklearn.preprocessing import OneHotEncoder
 = OneHotEncoder(categorical_features = [0])
x = ohe.fit_transform(price).toarray()
x
# Out:
# C:\Users\manoj kumar\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:371: FutureWarning: The handling of integer data will change in version 0.22. Currently, the categories are determined based on the range [0, max(values)], while in the future they will be determined based on the unique values.
# If you want the future behaviour and silence this warning, you can specify "categories='auto'".
# In case you used a LabelEncoder before this OneHotEncoder to convert the categories to integers, then you can now use the OneHotEncoder directly.
#   warnings.warn(msg, FutureWarning)
# C:\Users\manoj kumar\Anaconda3\lib\site-packages\sklearn\preprocessing\_encoders.py:392: DeprecationWarning: The 'categorical_features' keyword is deprecated in version 0.20 and will be removed in 0.22. You can use the ColumnTransformer instead.
#   "use the ColumnTransformer instead.", DeprecationWarning)
# array([[1.00e+00, 0.00e+00, 0.00e+00, 2.60e+03, 5.50e+05],
# ...

# %%
x=pd.DataFrame(x)

# %%
x
# Out:
#       0    1    2       3         4
# 0   1.0  0.0  0.0  2600.0  550000.0
# 1   1.0  0.0  0.0  3000.0  565000.0
# 2   1.0  0.0  0.0  3200.0  610000.0
# 3   1.0  0.0  0.0  3600.0  680000.0
# 4   1.0  0.0  0.0  4000.0  725000.0
# 5   0.0  0.0  1.0  2600.0  585000.0
# 6   0.0  0.0  1.0  2800.0  615000.0
# 7   0.0  0.0  1.0  3300.0  650000.0
# 8   0.0  0.0  1.0  3600.0  710000.0
# 9   0.0  1.0  0.0  2600.0  575000.0
# 10  0.0  1.0  0.0  2900.0  600000.0
# 11  0.0  1.0  0.0  3100.0  620000.0
# 12  0.0  1.0  0.0  3600.0  695000.0

# %% [markdown]
#  # Splitting the data

# %%
price
# Out:
#     town  area   price
# 0      0  2600  550000
# 1      0  3000  565000
# 2      0  3200  610000
# 3      0  3600  680000
# 4      0  4000  725000
# 5      2  2600  585000
# 6      2  2800  615000
# 7      2  3300  650000
# 8      2  3600  710000
# 9      1  2600  575000
# 10     1  2900  600000
# 11     1  3100  620000
# 12     1  3600  695000

# %%
X = price.iloc[:,0:2] # Preparing input variables
X
# Out:
#     town  area
# 0      0  2600
# 1      0  3000
# 2      0  3200
# 3      0  3600
# 4      0  4000
# 5      2  2600
# 6      2  2800
# 7      2  3300
# 8      2  3600
# 9      1  2600
# 10     1  2900
# 11     1  3100
# 12     1  3600

# %%
y = price.price
y
# Out:
# 0     550000
# 1     565000
# 2     610000
# 3     680000
# 4     725000
# 5     585000
# 6     615000
# 7     650000
# 8     710000
# 9     575000
# 10    600000
# 11    620000
# 12    695000
# Name: price, dtype: int64

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2, random_state = 0)

# %%
print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (10, 2)
# (3, 2)
# (10,)
# (3,)

# %% [markdown]
# # Feature Scaling

# %%
from sklearn.preprocessing import scale
a = scale(price)
a
# Out:
# C:\Users\manoj kumar\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: DataConversionWarning: Data with input dtype int32, int64 were all converted to float64 by the scale function.
# array([[-1.11417203, -1.25237795, -1.43117686],
#        [-1.11417203, -0.33514339, -1.1602259 ],
#        [-1.11417203,  0.12347388, -0.34737302],
#        [-1.11417203,  1.04070844,  0.91706478],
#        [-1.11417203,  1.95794299,  1.72991766],
#        [ 1.29986737, -1.25237795, -0.79895796],
#        [ 1.29986737, -0.79376067, -0.25705604],
#        [ 1.29986737,  0.35278252,  0.37516287],
#        [ 1.29986737,  1.04070844,  1.4589667 ],
#        [ 0.09284767, -1.25237795, -0.97959193],
#        [ 0.09284767, -0.56445203, -0.528007  ],
#        [ 0.09284767, -0.10583476, -0.16673905],
#        [ 0.09284767,  1.04070844,  1.18801574]])

# %%
a= pd.DataFrame(a)
a
# Out:
#            0         1         2
# 0  -1.114172 -1.252378 -1.431177
# 1  -1.114172 -0.335143 -1.160226
# 2  -1.114172  0.123474 -0.347373
# 3  -1.114172  1.040708  0.917065
# 4  -1.114172  1.957943  1.729918
# 5   1.299867 -1.252378 -0.798958
# 6   1.299867 -0.793761 -0.257056
# 7   1.299867  0.352783  0.375163
# 8   1.299867  1.040708  1.458967
# 9   0.092848 -1.252378 -0.979592
# 10  0.092848 -0.564452 -0.528007
# 11  0.092848 -0.105835 -0.166739
# 12  0.092848  1.040708  1.188016
